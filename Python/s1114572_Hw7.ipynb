# %%
def analyze_scores(scores):
  math_scores, english_scores, science_scores = zip(*scores)

  max=max(math_scores)
  min=min(math_scores)
  total=sum(math_scores)
  average=total/len(math_scores)
  print(max)
  print(min)
  print(average)
  print(total)




student_scores = [
 (85, 90, 78), # 學生 1 的成績
 (92, 88, 84), # 學生 2 的成績
 (76, 95, 80), # 學生 3 的成績
 (88, 72, 94) # 學生 4 的成績
]
analyze_scores(student_scores)
# Out:
# ---------------------------------------------------------------------------
# UnboundLocalError                         Traceback (most recent call last)
# <ipython-input-4-58b5d070cc4a> in <cell line: 22>()
#      20  (88, 72, 94) # 學生 4 的成績
#      21 ]
# ---> 22 analyze_scores(student_scores)
#
# <ipython-input-4-58b5d070cc4a> in analyze_scores(scores)
#       2   math_scores, english_scores, science_scores = zip(*scores)
#       3
# ----> 4   max=max(math_scores)
#       5   min=min(math_scores)
#       6   total=sum(math_scores)
#
# UnboundLocalError: local variable 'max' referenced before assignment

# %%
def analyze_scores(scores):
  math_scores, english_scores, science_scores = zip(*scores)

  max_scores=max(math_scores)
  min_scores=min(math_scores)
  total=sum(math_scores)
  average=total/len(math_scores)

  max_scores=max(english_scores)
  min_scores=min(english_scores)
  total=sum(english_scores)
  average=total/len(english_scores)

  max_scores=max(science_scores)
  min_scores=min(science_scores)
  total=sum(science_scores)
  average=total/len(science_scores)




student_scores = [
 (85, 90, 78), # 學生 1 的成績
 (92, 88, 84), # 學生 2 的成績
 (76, 95, 80), # 學生 3 的成績
 (88, 72, 94) # 學生 4 的成績
]
print("排序後的成績")
sort_scores=student_scores.sorted()
print(sort_scores)
analyze_scores(student_scores)
# Out:
# 排序後的成績
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-7-3d2bb71218f0> in <cell line: 29>()
#      27 ]
#      28 print("排序後的成績")
# ---> 29 sort_scores=student_scores.sorted()
#      30 print(sort_scores)
#      31 analyze_scores(student_scores)
#
# AttributeError: 'list' object has no attribute 'sorted'

# %%
def analyze_scores(scores):
  math_scores, english_scores, science_scores = zip(*scores)

  max_mathscores=max(math_scores)
  min_mathscores=min(math_scores)
  mathtotal=sum(math_scores)
  mathaverage=mathtotal/len(math_scores)

  max_englishscores=max(english_scores)
  min_englishscores=min(english_scores)
  englishtotal=sum(english_scores)
  englishaverage=englishtotal/len(english_scores)

  max_sciencescores=max(science_scores)
  min_sciencescores=min(science_scores)
  sciencetotal=sum(science_scores)
  scienceaverage=sciencetotal/len(science_scores)

  results={math:{"max":max_mathscores,"min":min_mathscores,"average":mathaverage,"total":mathtotal},english:{"max":max_englishscores,"min":min_englishscores,"average":englishaverage,"total":englishtotal},science:{"max":max_sciencescores,"min":min_sciencescores,"average":scienceaverage,"total":sciencetotal}}
  return results


student_scores = [
 (85, 90, 78), # 學生 1 的成績
 (92, 88, 84), # 學生 2 的成績
 (76, 95, 80), # 學生 3 的成績
 (88, 72, 94) # 學生 4 的成績
]

print("排序後的成績")
sorted_scores = [tuple(sorted(student)) for student in student_scores]
print(sorted_scores)
print("分析結果：")
print("{")
print(analyze_scores(student_scores))
print("}")
analyze_scores(student_scores)
# Out:
# 排序後的成績
# [(78, 85, 90), (84, 88, 92), (76, 80, 95), (72, 88, 94)]
# 分析結果：
# {
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-12-da273a86cf9c> in <cell line: 35>()
#      33 print("分析結果：")
#      34 print("{")
# ---> 35 print(analyze_scores(student_scores))
#      36 print("}")
#      37 analyze_scores(student_scores)
#
# <ipython-input-12-da273a86cf9c> in analyze_scores(scores)
#      17   scienceaverage=sciencetotal/len(science_scores)
#      18
# ---> 19   results={math:{"max":max_mathscores,"min":min_mathscores,"average":mathaverage,"total":mathtotal},english:{"max":max_englishscores,"min":min_englishscores,"average":englishaverage,"total":englishtotal},science:{"max":max_sciencescores,"min":min_sciencescores,"average":scienceaverage,"total":sciencetotal}}
#      20   return results
#      21
#
# NameError: name 'math' is not defined

# %%
def analyze_scores(scores):
  math_scores, english_scores, science_scores = zip(*scores)

  max_mathscores=max(math_scores)
  min_mathscores=min(math_scores)
  mathtotal=sum(math_scores)
  mathaverage=mathtotal/len(math_scores)

  max_englishscores=max(english_scores)
  min_englishscores=min(english_scores)
  englishtotal=sum(english_scores)
  englishaverage=englishtotal/len(english_scores)

  max_sciencescores=max(science_scores)
  min_sciencescores=min(science_scores)
  sciencetotal=sum(science_scores)
  scienceaverage=sciencetotal/len(science_scores)

  results={"math":{"max":max_mathscores,"min":min_mathscores,"average":mathaverage,"total":mathtotal},"english":{"max":max_englishscores,"min":min_englishscores,"average":englishaverage,"total":englishtotal},"science":{"max":max_sciencescores,"min":min_sciencescores,"average":scienceaverage,"total":sciencetotal}}
  return results


student_scores = [
 (85, 90, 78), # 學生 1 的成績
 (92, 88, 84), # 學生 2 的成績
 (76, 95, 80), # 學生 3 的成績
 (88, 72, 94) # 學生 4 的成績
]

print("排序後的成績")
sorted_scores = [tuple(sorted(student)) for student in student_scores]
print(sorted_scores)
print("分析結果：")
print("{")
print(analyze_scores(student_scores))
print("}")
# Out:
# 排序後的成績
# [(78, 85, 90), (84, 88, 92), (76, 80, 95), (72, 88, 94)]
# 分析結果：
# {
# {'math': {'max': 92, 'min': 76, 'average': 85.25, 'total': 341}, 'english': {'max': 95, 'min': 72, 'average': 86.25, 'total': 345}, 'science': {'max': 94, 'min': 78, 'average': 84.0, 'total': 336}}
# }

# %%
import json
def analyze_scores(scores):
  math_scores, english_scores, science_scores = zip(*scores)

  max_mathscores=max(math_scores)
  min_mathscores=min(math_scores)
  mathtotal=sum(math_scores)
  mathaverage=mathtotal/len(math_scores)

  max_englishscores=max(english_scores)
  min_englishscores=min(english_scores)
  englishtotal=sum(english_scores)
  englishaverage=englishtotal/len(english_scores)

  max_sciencescores=max(science_scores)
  min_sciencescores=min(science_scores)
  sciencetotal=sum(science_scores)
  scienceaverage=sciencetotal/len(science_scores)

  results={
      "math":{"max":max_mathscores,"min":min_mathscores,"average":mathaverage,"total":mathtotal},
      "english":{"max":max_englishscores,"min":min_englishscores,"average":englishaverage,"total":englishtotal},
      "science":{"max":max_sciencescores,"min":min_sciencescores,"average":scienceaverage,"total":sciencetotal}
  }
  return results


student_scores = [
 (85, 90, 78), # 學生 1 的成績
 (92, 88, 84), # 學生 2 的成績
 (76, 95, 80), # 學生 3 的成績
 (88, 72, 94) # 學生 4 的成績
]

print("排序後的成績")
sorted_scores = [tuple(sorted(student)) for student in student_scores]
print(sorted_scores)
print("分析結果：")
print("{")
result=analyze_scores(student_scores)
print(result)
print("}")

print("總分的百位與餘數：")
for subject, data in result.items():
  quotient, remainder = divmod(data["total"], 100)
  print(f"{subject}：商={quotient}, 餘數={remainder}")
# Out:
# 排序後的成績
# [(78, 85, 90), (84, 88, 92), (76, 80, 95), (72, 88, 94)]
# 分析結果：
# {
# {'math': {'max': 92, 'min': 76, 'average': 85.25, 'total': 341}, 'english': {'max': 95, 'min': 72, 'average': 86.25, 'total': 345}, 'science': {'max': 94, 'min': 78, 'average': 84.0, 'total': 336}}
# }
# 總分的百位與餘數：
# math：商=3, 餘數=41
# english：商=3, 餘數=45
# science：商=3, 餘數=36

# %%
import json
def analyze_scores(scores):
  math_scores, english_scores, science_scores = zip(*scores)

  max_mathscores=max(math_scores)
  min_mathscores=min(math_scores)
  mathtotal=sum(math_scores)
  mathaverage=mathtotal/len(math_scores)

  max_englishscores=max(english_scores)
  min_englishscores=min(english_scores)
  englishtotal=sum(english_scores)
  englishaverage=englishtotal/len(english_scores)

  max_sciencescores=max(science_scores)
  min_sciencescores=min(science_scores)
  sciencetotal=sum(science_scores)
  scienceaverage=sciencetotal/len(science_scores)

  results = {
        "math": {"max": max_mathscores, "min": min_mathscores, "total": mathtotal, "average": mathaverage},
        "english": {"max": max_englishscores, "min": min_englishscores, "total": englishtotal, "average": englishaverage},
        "science": {"max": max_sciencescores, "min": min_sciencescores, "total": sciencetotal, "average": scienceaverage},
  }
  return results


student_scores = [
 (85, 90, 78), # 學生 1 的成績
 (92, 88, 84), # 學生 2 的成績
 (76, 95, 80), # 學生 3 的成績
 (88, 72, 94) # 學生 4 的成績
]

print("排序後的成績")
sorted_scores = [tuple(sorted(student)) for student in student_scores]
print(sorted_scores)
print()
print("分析結果：")
print("{")
result=analyze_scores(student_scores)
for key, value in result.items():
  print(f'    "{key}": {value},')

print("}")
print()
print("總分的百位與餘數：")
for subject, data in result.items():
  quotient, remainder = divmod(data["total"], 100)
  if subject == "math":
    print(f"數學：商={quotient}, 餘數={remainder}")
  elif subject == "english":
    print(f"英文：商={quotient}, 餘數={remainder}")
  elif subject == "science":
    print(f"科學：商={quotient}, 餘數={remainder}")
# Out:
# 排序後的成績
# [(78, 85, 90), (84, 88, 92), (76, 80, 95), (72, 88, 94)]
#
# 分析結果：
# {
#     "math": {'max': 92, 'min': 76, 'total': 341, 'average': 85.25},
#     "english": {'max': 95, 'min': 72, 'total': 345, 'average': 86.25},
#     "science": {'max': 94, 'min': 78, 'total': 336, 'average': 84.0},
# }
#
# 總分的百位與餘數：
# 數學：商=3, 餘數=41
# 英文：商=3, 餘數=45
# 科學：商=3, 餘數=36

# %%
import json
def analyze_scores(scores):
  math_scores, english_scores, science_scores = zip(*scores)

  max_mathscores=max(math_scores)
  min_mathscores=min(math_scores)
  mathtotal=sum(math_scores)
  mathaverage=mathtotal/len(math_scores)

  max_englishscores=max(english_scores)
  min_englishscores=min(english_scores)
  englishtotal=sum(english_scores)
  englishaverage=englishtotal/len(english_scores)

  max_sciencescores=max(science_scores)
  min_sciencescores=min(science_scores)
  sciencetotal=sum(science_scores)
  scienceaverage=sciencetotal/len(science_scores)

  results = {
        "math": {"max": max_mathscores, "min": min_mathscores, "total": mathtotal, "average": mathaverage},
        "english": {"max": max_englishscores, "min": min_englishscores, "total": englishtotal, "average": englishaverage},
        "science": {"max": max_sciencescores, "min": min_sciencescores, "total": sciencetotal, "average": scienceaverage},
  }
  return results

student_score=[]
student_num=int(input("請輸入學生人數："))
for i in range(student_num):
  print(f"請輸入學生 {i + 1} 的成績：")
  math = int(input("  數學成績："))
  english = int(input("  英文成績："))
  science = int(input("  科學成績："))
  student_score.append((math, english, science))
print()

print("排序後的成績")
sorted_score = [tuple(sorted(students)) for students in student_score]
print(sorted_score)
print()
print("分析結果：")
print("{")
result=analyze_scores(student_score)
for key, value in result.items():
  print(f'    "{key}": {value},')

print("}")
print()
print("總分的百位與餘數：")
for subject, data in result.items():
  quotient, remainder = divmod(data["total"], 100)
  if subject == "math":
    print(f"數學：商={quotient}, 餘數={remainder}")
  elif subject == "english":
    print(f"英文：商={quotient}, 餘數={remainder}")
  elif subject == "science":
    print(f"科學：商={quotient}, 餘數={remainder}")
# Out:
# 請輸入學生人數：2
# 請輸入學生 1 的成績：
#   數學成績：90
#   英文成績：80
#   科學成績：99
# 請輸入學生 2 的成績：
#   數學成績：87
#   英文成績：68
#   科學成績：90
#
# 排序後的成績
# [(80, 90, 99), (68, 87, 90)]
#
# 分析結果：
# {
#     "math": {'max': 90, 'min': 87, 'total': 177, 'average': 88.5},
#     "english": {'max': 80, 'min': 68, 'total': 148, 'average': 74.0},
#     "science": {'max': 99, 'min': 90, 'total': 189, 'average': 94.5},
# }
#
# 總分的百位與餘數：
# 數學：商=1, 餘數=77
# 英文：商=1, 餘數=48
# 科學：商=1, 餘數=89
